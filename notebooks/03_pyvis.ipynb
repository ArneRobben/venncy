# %% [markdown]
# # pyvis renderer
#
# Interactive vis.js–based Venn diagram that renders to a standalone HTML file.
#
# ```bash
# pip install venncy[pyvis]
# ```
#
# > **Note:** pyvis output relies on JavaScript (vis.js) which cannot execute
# > inside VS Code's notebook viewer. Each cell writes an HTML file and opens it
# > in your default browser. In Jupyter Lab/Notebook this renders inline.

# %%
from venncy.renderers.pyvis import plot_venn2
from pathlib import Path
import webbrowser

def show_venn(path):
    """Open the generated HTML file in the default browser."""
    full_path = Path(path).resolve()
    webbrowser.open(f"file://{full_path}")

# Just provide the three areas — the renderer does the rest
net = plot_venn2(area_a=10, area_b=5, area_ab=2, labels=("Dogs", "Cats"), output_path="venn_basic.html")
show_venn("venn_basic.html")

# %% [markdown]
# ## No overlap

# %%
net = plot_venn2(area_a=10, area_b=3, area_ab=0, output_path="venn_no_overlap.html")
show_venn("venn_no_overlap.html")

# %% [markdown]
# ## Full containment

# %%
net = plot_venn2(area_a=10, area_b=3, area_ab=3, output_path="venn_containment.html")
show_venn("venn_containment.html")
# Out:
# <iframe srcdoc="&lt;html&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;utf-8&quot;&gt;
#
#             &lt;script src=&quot;lib/bindings/utils.js&quot;&gt;&lt;/script&gt;
#             &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/dist/vis-network.min.css&quot; integrity=&quot;sha512-WgxfT5LWjfszlPHXRmBWHkV2eceiWTOBvrKCNbdgDYTHrT2AeLCGbF4sZlZw3UMN3WtL0tGUoIAKsu8mllg/XA==&quot; crossorigin=&quot;anonymous&quot; referrerpolicy=&quot;no-referrer&quot; /&gt;
#             &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/vis-network.min.js&quot; integrity=&quot;sha512-LnvoEWDFrqGHlHmDD2101OrLcbsfkrzoSpvtSQtxK3RMnRV0eOkhhBN2dXHKRrUU8p2DGRTk35n4O8nWSVe1mQ==&quot; crossorigin=&quot;anonymous&quot; referrerpolicy=&quot;no-referrer&quot;&gt;&lt;/script&gt;
#
#
# &lt;center&gt;
# &lt;h1&gt;&lt;/h1&gt;
# &lt;/center&gt;
#
# &lt;!-- &lt;link rel=&quot;stylesheet&quot; href=&quot;../node_modules/vis/dist/vis.min.css&quot; type=&quot;text/css&quot; /&gt;
# &lt;script type=&quot;text/javascript&quot; src=&quot;../node_modules/vis/dist/vis.js&quot;&gt; &lt;/script&gt;--&gt;
#         &lt;link
#           href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/css/bootstrap.min.css&quot;
#           rel=&quot;stylesheet&quot;
#           integrity=&quot;sha384-eOJMYsd53ii+scO/bJGFsiCZc+5NDVN2yr8+0RDqr0Ql0h+rP48ckxlpbzKgwra6&quot;
#           crossorigin=&quot;anonymous&quot;
#         /&gt;
#         &lt;script
#           src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/js/bootstrap.bundle.min.js&quot;
#           integrity=&quot;sha384-JEW9xMcG8R+pH31jmWH6WWP0WintQrMb4s7ZOdauHnUtxwoG2vI5DkLtS3qm9Ekf&quot;
#           crossorigin=&quot;anonymous&quot;
#         &gt;&lt;/script&gt;
#
#
#         &lt;center&gt;
#           &lt;h1&gt;&lt;/h1&gt;
#         &lt;/center&gt;
#         &lt;style type=&quot;text/css&quot;&gt;
#
#              #mynetwork {
#                  width: 800px;
#                  height: 800px;
#                  background-color: #ffffff;
#                  border: 1px solid lightgray;
#                  position: relative;
#                  float: left;
#              }
#
#
#
#
#
#
#         &lt;/style&gt;
#     &lt;/head&gt;
#
#
#     &lt;body&gt;
#         &lt;div class=&quot;card&quot; style=&quot;width: 100%&quot;&gt;
#
#
#             &lt;div id=&quot;mynetwork&quot; class=&quot;card-body&quot;&gt;&lt;/div&gt;
#         &lt;/div&gt;
#
#
#
#
#         &lt;script type=&quot;text/javascript&quot;&gt;
#
#               // initialize global variables.
#               var edges;
#               var nodes;
#               var allNodes;
#               var allEdges;
#               var nodeColors;
#               var originalNodes;
#               var network;
#               var container;
#               var options, data;
#               var filter = {
#                   item : &#x27;&#x27;,
#                   property : &#x27;&#x27;,
#                   value : []
#               };
#
#
#
#
#
#               // This method is responsible for drawing the graph, returns the drawn network
#               function drawGraph() {
#                   var container = document.getElementById(&#x27;mynetwork&#x27;);
#
#
#
#                   // parsing and collecting nodes and edges from the python
#                   nodes = new vis.DataSet([{&quot;borderWidth&quot;: 2, &quot;color&quot;: &quot;rgba(66,135,245,0.35)&quot;, &quot;fixed&quot;: true, &quot;id&quot;: &quot;A&quot;, &quot;label&quot;: &quot;A&quot;, &quot;physics&quot;: false, &quot;shape&quot;: &quot;dot&quot;, &quot;size&quot;: 340.0, &quot;x&quot;: 400.0, &quot;y&quot;: 400.0}, {&quot;borderWidth&quot;: 2, &quot;color&quot;: &quot;rgba(255,159,64,0.35)&quot;, &quot;fixed&quot;: true, &quot;id&quot;: &quot;B&quot;, &quot;label&quot;: &quot;B&quot;, &quot;physics&quot;: false, &quot;shape&quot;: &quot;dot&quot;, &quot;size&quot;: 186.22566955175648, &quot;x&quot;: 553.7743304482435, &quot;y&quot;: 400.0}]);
#                   edges = new vis.DataSet([]);
#
#                   nodeColors = {};
#                   allNodes = nodes.get({ returnType: &quot;Object&quot; });
#                   for (nodeId in allNodes) {
#                     nodeColors[nodeId] = allNodes[nodeId].color;
#                   }
#                   allEdges = edges.get({ returnType: &quot;Object&quot; });
#                   // adding nodes and edges to the graph
#                   data = {nodes: nodes, edges: edges};
#
#                   var options = {&quot;physics&quot;: {&quot;enabled&quot;: false}, &quot;interaction&quot;: {&quot;dragNodes&quot;: false}, &quot;nodes&quot;: {&quot;font&quot;: {&quot;size&quot;: 16}}};
#
#
#
#
#
#
#                   network = new vis.Network(container, data, options);
#
#
#
#
#
#
#
#
#
#
#                   return network;
#
#               }
#               drawGraph();
#         &lt;/script&gt;
#     &lt;/body&gt;
# &lt;/html&gt;" width="200" height="200" frameborder="0"></iframe>

# %% [markdown]
# ## Customisation
#
# You can pass custom colours, canvas dimensions, and output path.

# %%
net = plot_venn2(
    area_a=20,
    area_b=8,
    area_ab=5,
    labels=("Python", "R"),
    colors=("rgba(50,200,50,0.35)", "rgba(200,50,50,0.35)"),
    canvas_width=1000,
    canvas_height=600,
    output_path="venn_custom.html",
)
show_venn("venn_custom.html")
# Out:
# <iframe srcdoc="&lt;html&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;utf-8&quot;&gt;
#
#             &lt;script src=&quot;lib/bindings/utils.js&quot;&gt;&lt;/script&gt;
#             &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/dist/vis-network.min.css&quot; integrity=&quot;sha512-WgxfT5LWjfszlPHXRmBWHkV2eceiWTOBvrKCNbdgDYTHrT2AeLCGbF4sZlZw3UMN3WtL0tGUoIAKsu8mllg/XA==&quot; crossorigin=&quot;anonymous&quot; referrerpolicy=&quot;no-referrer&quot; /&gt;
#             &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/vis-network/9.1.2/dist/vis-network.min.js&quot; integrity=&quot;sha512-LnvoEWDFrqGHlHmDD2101OrLcbsfkrzoSpvtSQtxK3RMnRV0eOkhhBN2dXHKRrUU8p2DGRTk35n4O8nWSVe1mQ==&quot; crossorigin=&quot;anonymous&quot; referrerpolicy=&quot;no-referrer&quot;&gt;&lt;/script&gt;
#
#
# &lt;center&gt;
# &lt;h1&gt;&lt;/h1&gt;
# &lt;/center&gt;
#
# &lt;!-- &lt;link rel=&quot;stylesheet&quot; href=&quot;../node_modules/vis/dist/vis.min.css&quot; type=&quot;text/css&quot; /&gt;
# &lt;script type=&quot;text/javascript&quot; src=&quot;../node_modules/vis/dist/vis.js&quot;&gt; &lt;/script&gt;--&gt;
#         &lt;link
#           href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/css/bootstrap.min.css&quot;
#           rel=&quot;stylesheet&quot;
#           integrity=&quot;sha384-eOJMYsd53ii+scO/bJGFsiCZc+5NDVN2yr8+0RDqr0Ql0h+rP48ckxlpbzKgwra6&quot;
#           crossorigin=&quot;anonymous&quot;
#         /&gt;
#         &lt;script
#           src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.0.0-beta3/dist/js/bootstrap.bundle.min.js&quot;
#           integrity=&quot;sha384-JEW9xMcG8R+pH31jmWH6WWP0WintQrMb4s7ZOdauHnUtxwoG2vI5DkLtS3qm9Ekf&quot;
#           crossorigin=&quot;anonymous&quot;
#         &gt;&lt;/script&gt;
#
#
#         &lt;center&gt;
#           &lt;h1&gt;&lt;/h1&gt;
#         &lt;/center&gt;
#         &lt;style type=&quot;text/css&quot;&gt;
#
#              #mynetwork {
#                  width: 1000px;
#                  height: 600px;
#                  background-color: #ffffff;
#                  border: 1px solid lightgray;
#                  position: relative;
#                  float: left;
#              }
#
#
#
#
#
#
#         &lt;/style&gt;
#     &lt;/head&gt;
#
#
#     &lt;body&gt;
#         &lt;div class=&quot;card&quot; style=&quot;width: 100%&quot;&gt;
#
#
#             &lt;div id=&quot;mynetwork&quot; class=&quot;card-body&quot;&gt;&lt;/div&gt;
#         &lt;/div&gt;
#
#
#
#
#         &lt;script type=&quot;text/javascript&quot;&gt;
#
#               // initialize global variables.
#               var edges;
#               var nodes;
#               var allNodes;
#               var allEdges;
#               var nodeColors;
#               var originalNodes;
#               var network;
#               var container;
#               var options, data;
#               var filter = {
#                   item : &#x27;&#x27;,
#                   property : &#x27;&#x27;,
#                   value : []
#               };
#
#
#
#
#
#               // This method is responsible for drawing the graph, returns the drawn network
#               function drawGraph() {
#                   var container = document.getElementById(&#x27;mynetwork&#x27;);
#
#
#
#                   // parsing and collecting nodes and edges from the python
#                   nodes = new vis.DataSet([{&quot;borderWidth&quot;: 2, &quot;color&quot;: &quot;rgba(50,200,50,0.35)&quot;, &quot;fixed&quot;: true, &quot;id&quot;: &quot;Python&quot;, &quot;label&quot;: &quot;Python&quot;, &quot;physics&quot;: false, &quot;shape&quot;: &quot;dot&quot;, &quot;size&quot;: 240.0, &quot;x&quot;: 300.0, &quot;y&quot;: 300.0}, {&quot;borderWidth&quot;: 2, &quot;color&quot;: &quot;rgba(200,50,50,0.35)&quot;, &quot;fixed&quot;: true, &quot;id&quot;: &quot;R&quot;, &quot;label&quot;: &quot;R&quot;, &quot;physics&quot;: false, &quot;shape&quot;: &quot;dot&quot;, &quot;size&quot;: 151.7893276880822, &quot;x&quot;: 493.0667559016732, &quot;y&quot;: 300.0}]);
#                   edges = new vis.DataSet([]);
#
#                   nodeColors = {};
#                   allNodes = nodes.get({ returnType: &quot;Object&quot; });
#                   for (nodeId in allNodes) {
#                     nodeColors[nodeId] = allNodes[nodeId].color;
#                   }
#                   allEdges = edges.get({ returnType: &quot;Object&quot; });
#                   // adding nodes and edges to the graph
#                   data = {nodes: nodes, edges: edges};
#
#                   var options = {&quot;physics&quot;: {&quot;enabled&quot;: false}, &quot;interaction&quot;: {&quot;dragNodes&quot;: false}, &quot;nodes&quot;: {&quot;font&quot;: {&quot;size&quot;: 16}}};
#
#
#
#
#
#
#                   network = new vis.Network(container, data, options);
#
#
#
#
#
#
#
#
#
#
#                   return network;
#
#               }
#               drawGraph();
#         &lt;/script&gt;
#     &lt;/body&gt;
# &lt;/html&gt;" width="1020" height="620" frameborder="0"></iframe>
